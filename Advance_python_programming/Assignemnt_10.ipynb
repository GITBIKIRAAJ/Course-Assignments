# %% [markdown]
# Q1. **What is the difference between `__getattr__` and `__getattribute__`?**

# %% [markdown]
# **Ans**:
#
# `__getattribute__` is used to find an attribute of a class. It raises an AttributeError if it fails to find an attribute of a class. `__getattr__` is implemented latter if AttributeError is generated by `__getattribute__`, but for this `__getattribute__` and` __getattr__` both has to be defined in same class. If no attribute is found, `__getattr__` returns a default value. So key differece is that `__getattr__` is called for attributes that don't actually exist on a class.

# %% [markdown]
# Q2. **What is the difference between properties and descriptors?**

# %% [markdown]
# **Ans: The differences between Properties and Descriptors is:**
#
# `Properties`: With Properties we can bind getter, setter and delete functions together with an attribute name, using the built-in property function or @property decorator. When we do this, each reference to an attribute looks like simple, direct access, but involes the appropriate function of the object.
#
# `Descriptor`: With Descriptor we can bind getter, setter and delete functions into a seperate class. we then assign an object of this class to the attribute name in our main class. When we do this, each reference to an attribute looks like simple, direct access but invokes an appropriate function of descriptor object.
#
# **There are several key differences between properties and descriptors:**
#
# - Properties are defined using the property() built-in function, whereas descriptors are implemented by defining special methods in a class.
# - Properties are defined on a per-instance basis, whereas descriptors are defined at the class level and apply to all instances of the class.
# - Descriptors have more control over attribute access, as they can define behavior for all three attribute access operations (getting, setting, and deleting), whereas properties can only define behavior for getting and setting.

# %% [markdown]
# Q3. **What are the key differences in functionality between getattr and getattribute, as well as properties and descriptors?**

# %% [markdown]
# **Answer**:
#
# In Python, `getattr()` is a built-in function that can be used to retrieve the value of an attribute of an object. It takes an object and an attribute name as arguments, and returns the value of the attribute. If the attribute does not exist, getattr() can raise an AttributeError exception.
#
# `getattribute()` is a special method that is called by Python whenever you try to access an attribute of an object. It is similar to getattr(), but it is called automatically when you try to access an attribute, rather than being called explicitly in your code.
#
# Properties are a way to define special methods that are called when you try to access an attribute of an object. They allow you to customize the behavior of attribute access for a specific attribute, and can be used to implement getters, setters, and deleters for the attribute.
